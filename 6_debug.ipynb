# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.', 'explanation': 'The joke relies on double meanings and wordplay. Here\'s a breakdown of the explanation:\n\n1. **"Crusty"** - In this context, "crusty" has a double meaning. Crust is a part of a pizza, referring to the outer layer of bread. However, "crusty" can also describe someone or something that is irritable, moody, or difficult to deal with. The joke starts by setting up this dual meaning.\n\n2. **"Dough"** - Similar to "crusty," "dough" has multiple meanings. In baking, dough refers to the mixture of flour, water, and other ingredients used to make bread, including pizza crust. However, "dough" is also a slang term for money. In this joke, it takes on a third meaning - a psychological term for emotional or mental issues that one needs to work through in therapy.\n\n3. **Wordplay and pun** - The joke relies on a clever pl
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.', 'explanation': 'The joke relies on double meanings and wordplay. Here\'s a breakdown of the explanation:\n\n1. **"Crusty"** - In this context, "crusty" has a double meaning. Crust is a part of a pizza, referring to the outer layer of bread. However, "crusty" can also describe someone or something that is irritable, moody, or difficult to deal with. The joke starts by setting up this dual meaning.\n\n2. **"Dough"** - Similar to "crusty," "dough" has multiple meanings. In baking, dough refers to the mixture of flour, water, and other ingredients used to make bread, including pizza crust. However, "dough" is also a slang term for money. In this joke, it takes on a third meaning - a psychological term for emotional or mental issues that one needs to work through in therapy.\n\n3. **Wordplay and pun** - The joke relies on a clever p
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta go to therapy? \n\nBecause it was feeling a little "drained" and was struggling to "twist" its emotions.',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.', 'explanation': 'The joke relies on double meanings and wordplay. Here\'s a breakdown of the explanation:\n\n1. **"Crusty"** - In this context, "crusty" has a double meaning. Crust is a part of a pizza, referring to the outer layer of bread. However, "crusty" can also describe someone or something that is irritable, moody, or difficult to deal with. The joke starts by setting up this dual meaning.\n\n2. **"Dough"** - Similar to "crusty," "dough" has multiple meanings. In baking, dough refers to the mixture of flour, water, and other ingredients used to make bread, including pizza crust. However, "dough" is also a slang term for money. In this joke, it takes on a third meaning - a psychological term for emotional or mental issues that one needs to work through in therapy.\n\n3. **Wordplay and pun** - The joke relies on a clever pl
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.', 'explanation': 'The joke relies on double meanings and wordplay. Here\'s a breakdown of the explanation:\n\n1. **"Crusty"** - In this context, "crusty" has a double meaning. Crust is a part of a pizza, referring to the outer layer of bread. However, "crusty" can also describe someone or something that is irritable, moody, or difficult to deal with. The joke starts by setting up this dual meaning.\n\n2. **"Dough"** - Similar to "crusty," "dough" has multiple meanings. In baking, dough refers to the mixture of flour, water, and other ingredients used to make bread, including pizza crust. However, "dough" is also a slang term for money. In this joke, it takes on a third meaning - a psychological term for emotional or mental issues that one needs to work through in therapy.\n\n3. **Wordplay and pun** - The joke relies on a clever p
# ...

# %% [markdown]
# ### time travel with - thread_id and checkpointer_id
#
# - Re-run from that point/node and check how consistent the responses are
# - Try different temperature / help in prompt versioning / modify parameters like top p, k

# %%
# to view from particular thread and checkpoint
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f11b27e-0cb9-65fc-8000-9378c2362c3f"}})
# Out:
# StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f11b27e-0cb9-65fc-8000-9378c2362c3f'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-08T19:49:11.430911+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f11b27e-0cb9-65fb-bfff-7719da214510'}}, tasks=(PregelTask(id='e44a4a43-913f-90de-ff1e-9b47a6382022', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.'}),), interrupts=())

# %%
# to re-execute from particular checkpoint and thread id 
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f11b27e-0cb9-65fc-8000-9378c2362c3f"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'This joke is an example of a play on words, also known as a pun. Puns rely on multiple meanings of a word or phrase to create a humorous effect.\n\nIn this joke, the word "crusty" has a double meaning. \n\n1. A "crusty" pizza refers to a pizza with a crust (the outer layer of baked dough) that is hard and crispy.\n2. A "crusty" person is someone who is grumpy or has a rough exterior.\n\nThe joke is funny because it takes the literal meaning of a crusty pizza and applies it to the phrase "feeling a little crusty," which is a common idiomatic expression meaning feeling a bit sick or unwell. The punchline is a clever play on words, creating a humorous connection between the pizza and the doctor visit.'}

# %%
list(workflow.get_state_history(config1))

# %% [markdown]
# ### update state
#
# •	Modify state at a specific checkpoint.
# thread_id + checkpoint_id + state_key
#
# > Then re-run graph from that point to observe how node outputs change.
#
# Use cases:
# - Testing agent behaviour
# - Debugging incorrect state
# - Experimenting with responses

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f11b27e-0cb9-65fc-8000-9378c2362c3f", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f11b283-e344-647d-8001-cbf9ce6be49c'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f11b283-e344-647d-8001-cbf9ce6be49c'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-03-08T19:51:48.145062+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f11b27e-0cb9-65fc-8000-9378c2362c3f'}}, tasks=(PregelTask(id='5a02dc3f-d9c4-3d76-ec5e-04a8712281f2', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f11b283-e344-647d-8001-cbf9ce6be49c"}})
# Out:
# {'topic': 'samosa',
#  'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the pizza go to therapy? \n\nBecause it was feeling crusty and had a lot of dough to work through.', 'explanation': 'The joke is a play on words, combining a common phrase "crusty" with its literal meaning related to bread (the crust of a pizza) and a common idiomatic expression "feeling crusty" which can mean feeling irritable or grumpy.\n\nAdditionally, the phrase "a lot of dough to work through" is a pun on two different meanings of the word "dough." In the context of baking, dough refers to the mixture of flour, water, and other ingredients used to make bread or pizza crust. However, "dough" can also refer to money, as in "a lot of dough to work through," implying that the pizza has a lot of financial or emotional issues to deal with in therapy.\n\nThe joke relies on this double meaning of "dough" to create a humorous connection between the pizza\'s physical characteristics (crust) and its emotional state (feeling crusty 
# ...

# %% [markdown]
# ### Fault-Tolerance
# > If the graph crashes at any node during execution, it can resume from the last checkpoint instead of starting again.

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
